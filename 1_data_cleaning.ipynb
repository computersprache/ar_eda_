# %%
import numpy as np
import pandas as pd
import missingno as msno

# %%
df = pd.read_csv('king_county_house_pandas.csv')
df.isna().sum()
# Out:
# id                  0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2391
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement     452
# yr_built            0
# yr_renovated     3848
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# date                0
# price               0
# dtype: int64

# %%
# To check for space, odd characters, or capitals in column names
df.columns
# Out:
# Index(['id', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'date', 'price'],
#       dtype='object')

# %%
# To check duplicates in columns
df.duplicated().value_counts()
# Out:
# False    21597
# Name: count, dtype: int64

# %%
# To check data type in each column
df.dtypes
# Out:
# id                 int64
# bedrooms         float64
# bathrooms        float64
# sqft_living      float64
# sqft_lot         float64
# floors           float64
# waterfront       float64
# view             float64
# condition          int64
# grade              int64
# sqft_above       float64
# sqft_basement    float64
# yr_built           int64
# yr_renovated     float64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15    float64
# sqft_lot15       float64
# date              object
# price            float64
# dtype: object

# %%
# change data type to float
#df = df.astype({"bedrooms": int})
#df = df.astype({"bathrooms": int})
#df = df.astype({"floors": int})
#df = df.astype({"waterfront": bool})
#df = df.astype({"view": bool})
#!By changing to bool the NaN values disappear

# %%
# check the format of date
type(df["date"][0])
# change the format of date to datetime with format %Y/%m/%d
df["date"] = pd.to_datetime(df["date"], format='mixed')
type(df["date"][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.dtypes
# Out:
# id                        int64
# bedrooms                float64
# bathrooms               float64
# sqft_living             float64
# sqft_lot                float64
# floors                  float64
# waterfront              float64
# view                    float64
# condition                 int64
# grade                     int64
# sqft_above              float64
# sqft_basement           float64
# yr_built                  int64
# yr_renovated            float64
# zipcode                   int64
# lat                     float64
# long                    float64
# sqft_living15           float64
# sqft_lot15              float64
# date             datetime64[ns]
# price                   float64
# dtype: object

# %%
# add a column to the df for the house age
df['house_age'] = 2026 - df['yr_built']

# %%
# to find strange values in yr_renovated
df[df['yr_renovated'] > 2026]
# to remove the last 0 from the yr_renovated
df.loc[df['yr_renovated'] > 2026, 'yr_renovated'] //= 10
df.dtypes
# Out:
# id                        int64
# bedrooms                float64
# bathrooms               float64
# sqft_living             float64
# sqft_lot                float64
# floors                  float64
# waterfront              float64
# view                    float64
# condition                 int64
# grade                     int64
# sqft_above              float64
# sqft_basement           float64
# yr_built                  int64
# yr_renovated            float64
# zipcode                   int64
# lat                     float64
# long                    float64
# sqft_living15           float64
# sqft_lot15              float64
# date             datetime64[ns]
# price                   float64
# house_age                 int64
# dtype: object

# %%
# display number of missing values per column
df.isna().sum()
# Out:
# id                  0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2391
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement     452
# yr_built            0
# yr_renovated     3848
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# date                0
# price               0
# house_age           0
# dtype: int64

# %%
# plotting percentage of missing values per column
msno.bar(df)
# Out:
# <Axes: >

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
df.to_csv('king_county_house_pandas_cleaned.csv', index=False)
